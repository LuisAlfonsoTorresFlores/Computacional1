# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as mplt

import pylab as plt

import statsmodels.api as sm

df = pd.read_csv("/home/luistorres/Fisica_computacional/Eval1/GLB.Ts.csv",skiprows=2, names= ["Year","Jan", "Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec","JD","DN","DJF","MAM","JJA","SON"])

# %%
df.head(40)
# Out:
#     Year   Jan    Feb   Mar    Apr    May    Jun   Jul   Aug   Sep   Oct  \
# 0   1880 -0.87   -.49  -.53   -.69   -.40   -.52  -.50   .00  -.55  -.68
# 1   1881 -0.82   -.67  -.43   -.33   -.09  -1.15  -.62  -.32  -.46  -.62
# 2   1882  0.02   -.22  -.18   -.67   -.45  -1.07  -.79  -.19  -.11  -.39
# 3   1883 -0.77  -1.01  -.58   -.42   -.46    .29  -.15  -.29  -.58  -.67
# 4   1884 -0.62   -.48  -.60  -1.00  -1.26   -.90  -.97   .02  -.46  -.86
# 5   1885 -1.06   -.87  -.98  -1.04   -.60   -.98  -.70  -.22  -.17  -.16
# 6   1886 -0.86   -.93  -.77   -.67   -.61   -.94  -.44  -.79  -.47  -.86
# 7   1887 -0.95  -1.32  -.66   -.87   -.88   -.71  -.42  -.31  -.61  -.59
# 8   1888 -0.80   -.86  -.95   -.36   -.79   -.58  -.39  -.39  -.38  -.37
# 9   1889 -0.45    .04  -.03   -.01   -.01   -.31  -.51  -.68  -.44  -.29
# 10  1890 -0.69   -.69  -.71   -.57   -.98   -.62  -.70  -.68  -.39  -.34
# 11  1891 -1.04  -1.07  -.57   -.70   -.52   -.60  -.77  -.59  -.50  -.67
# 12  1892 -0.64   -.36  -.64   -.77   -.75   -.64  -.48  -.35  -.51  -.44
# 13  1893 -1.51  -1.05  -.64   -.72   -.83   -.81  -.24  -.43  -.36  -.18
# 14  1894 -0.91   -.64  -.41   -.68   -.71   -.53  -.43  -.42  -.53  -.19
# 15  1895 -0.76   -.85  -.59   -.53   -.35   -.34  -.53  -.24  -.17  -.17
# 16  1896 -0.29   -.33  -.58   -.53   -.47   -.46  -.24  -.40  -.17  -.09
# 17  1897 -0.32   -.55  -.37   -.16   -.30   -.21  -.15  -.38  -.20  -.31
# 18  1898 -0.19   -.54  -.86   -.62   -.68   -.33  -.40  -.29  -.09  -.46
# 19  1899 -0.49   -.65  -.45   -.31   -.46   -.60  -.34  -.35  -.04  -.33
# 20  1900 -0.61   -.12  -.23   -.21   -.22   -.16  -.42  -.23  -.13   .06
# 21  1901 -0.31   -.17  -.15   -.14   -.27   -.04  -.32  -.29  -.04  -.24
# 22  1902 -0.38   -.10  -.22   -.24   -.36   -.42  -.50  -.55  -.46  -.51
# 23  1903 -0.40   -.19  -.24   -.60   -.50   -.69  -.38  -.49  -.47  -.54
# 24  1904 -0.84   -.82  -.59   -.51   -.68   -.53  -.66  -.54  -.50  -.57
# 25  1905 -0.47  -1.04  -.28   -.34   -.38   -.35  -.49  -.32  -.26  -.40
# 26  1906 -0.22   -.41  -.38    .02   -.24   -.29  -.28  -.23  -.35  -.23
# 27  1907 -0.54   -.73  -.50   -.65   -.63   -.71  -.47  -.60  -.43  -.38
# 28  1908 -0.42   -.36  -.56   -.50   -.37   -.47  -.45  -.44  -.21  -.44
# 29  1909 -0.83   -.62  -.54   -.66   -.63   -.47  -.40  -.15  -.24  -.22
# 30  1910 -0.51   -.43  -.50   -.35   -.30   -.39  -.28  -.19  -.14  -.35
# 31  1911 -0.70   -.70  -.66   -.57   -.43   -.43  -.20  -.29  -.29  -.22
# 32  1912 -0.24   -.15  -.46   -.32   -.24   -.31  -.54  -.66  -.38  -.51
# 33  1913 -0.49   -.55  -.64   -.35   -.65   -.64  -.26  -.24  -.24  -.34
# 34  1914  0.09   -.09  -.10   -.25   -.06   -.12  -.26  -.13  -.13   .07
# 35  1915 -0.25    .02  -.09   -.06   -.24   -.28  -.02  -.22  -.04  -.14
# 36  1916 -0.14   -.19  -.48   -.34   -.40   -.55  -.40  -.16  -.22  -.20
# 37  1917 -0.57   -.78  -.83   -.57   -.84   -.51  -.04  -.43  -.36  -.54
# 38  1918 -0.68   -.66  -.55   -.58   -.81   -.47  -.53  -.53  -.23  -.02
# 39  1919 -0.35   -.29  -.17   -.17   -.21   -.23  -.13  -.11  -.24  -.12
#
#      Nov    Dec    JD    DN    DJF   MAM   JJA   SON
# 0   -.54   -.59  -.53   ***    ***  -.54  -.34  -.59
# 1   -.65   -.21  -.53  -.56   -.70  -.28  -.70  -.58
# 2   -.49   -.75  -.44  -.39   -.14  -.43  -.68  -.33
# 3   -.80   -.51  -.50  -.52   -.84  -.49  -.05  -.68
# 4   -.92  -1.07  -.76  -.71   -.54  -.95  -.62  -.75
# 5   -.44   -.17  -.62  -.69  -1.00  -.87  -.63  -.26
# 6   -.54   -.81  -.72  -.67   -.65  -.68  -.72  -.62
# 7   -.94   -.77  -.75  -.76  -1.02  -.80  -.48  -.71
# 8   -.10   -.30  -.52  -.56   -.81  -.70  -.45  -.28
# 9   -.63   -.54  -.32  -.30   -.24  -.02  -.50  -.45
# 10  -.80   -.58  -.65  -.64   -.64  -.75  -.67  -.51
# 11  -.64   -.12  -.65  -.69   -.89  -.60  -.66  -.60
# 12  -.67   -.67  -.58  -.53   -.37  -.72  -.49  -.54
# 13  -.25   -.46  -.62  -.64  -1.08  -.73  -.49  -.26
# 14  -.26   -.22  -.49  -.51   -.67  -.60  -.46  -.32
# 15  -.20   -.15  -.41  -.41   -.61  -.49  -.37  -.18
# 16  -.51   -.27  -.36  -.35   -.26  -.53  -.37  -.25
# 17  -.10   -.33  -.28  -.28   -.38  -.28  -.25  -.20
# 18  -.56   -.28  -.44  -.45   -.35  -.72  -.34  -.37
# 19  -.08   -.28  -.36  -.36   -.47  -.41  -.43  -.15
# 20  -.18   -.12  -.21  -.23   -.33  -.22  -.27  -.08
# 21  -.19   -.28  -.20  -.19   -.20  -.19  -.22  -.16
# 22  -.55   -.62  -.41  -.38   -.25  -.27  -.49  -.51
# 23  -.52   -.66  -.47  -.47   -.40  -.45  -.52  -.51
# 24  -.32   -.46  -.58  -.60   -.77  -.59  -.58  -.46
# 25  -.12   -.29  -.40  -.41   -.66  -.33  -.38  -.26
# 26  -.58   -.30  -.29  -.29   -.31  -.20  -.27  -.39
# 27  -.65   -.71  -.58  -.55   -.53  -.60  -.59  -.48
# 28  -.64   -.45  -.44  -.47   -.50  -.48  -.45  -.43
# 29  -.19   -.59  -.46  -.45   -.64  -.61  -.34  -.22
# 30  -.58   -.70  -.39  -.38   -.51  -.38  -.29  -.36
# 31  -.18   -.31  -.42  -.45   -.70  -.55  -.31  -.23
# 32  -.48   -.38  -.39  -.38   -.23  -.34  -.50  -.46
# 33  -.20   -.01  -.38  -.42   -.47  -.55  -.38  -.26
# 34  -.38   -.27  -.14  -.11   -.01  -.13  -.17  -.14
# 35   .01   -.16  -.12  -.13   -.17  -.13  -.17  -.06
# 36  -.43   -.85  -.36  -.31   -.16  -.41  -.37  -.29
# 37  -.39   -.97  -.57  -.56   -.73  -.75  -.32  -.43
# 38  -.29   -.40  -.48  -.53   -.77  -.65  -.51  -.18
# 39  -.47   -.35  -.24  -.24   -.35  -.18  -.16  -.28

# %%
df.describe()
# Out:
#               Year         Jan
# count   138.000000  138.000000
# mean   1948.500000   -0.022681
# std      39.981246    0.530615
# min    1880.000000   -1.510000
# 25%    1914.250000   -0.347500
# 50%    1948.500000   -0.055000
# 75%    1982.750000    0.315000
# max    2017.000000    1.340000

# %%
df.columns
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'JD', 'DN', 'DJF', 'MAM', 'JJA', 'SON'],
#       dtype='object')

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Year    0
# Jan     0
# Feb     0
# Mar     0
# Apr     0
# May     0
# Jun     0
# Jul     0
# Aug     0
# Sep     0
# Oct     0
# Nov     0
# Dec     0
# JD      0
# DN      0
# DJF     0
# MAM     0
# JJA     0
# SON     0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
df_clean.head()
# Out:
#    Year   Jan    Feb   Mar    Apr    May    Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.87   -.49  -.53   -.69   -.40   -.52  -.50   .00  -.55  -.68  -.54
# 1  1881 -0.82   -.67  -.43   -.33   -.09  -1.15  -.62  -.32  -.46  -.62  -.65
# 2  1882  0.02   -.22  -.18   -.67   -.45  -1.07  -.79  -.19  -.11  -.39  -.49
# 3  1883 -0.77  -1.01  -.58   -.42   -.46    .29  -.15  -.29  -.58  -.67  -.80
# 4  1884 -0.62   -.48  -.60  -1.00  -1.26   -.90  -.97   .02  -.46  -.86  -.92
#
#      Dec    JD    DN   DJF   MAM   JJA   SON
# 0   -.59  -.53   ***   ***  -.54  -.34  -.59
# 1   -.21  -.53  -.56  -.70  -.28  -.70  -.58
# 2   -.75  -.44  -.39  -.14  -.43  -.68  -.33
# 3   -.51  -.50  -.52  -.84  -.49  -.05  -.68
# 4  -1.07  -.76  -.71  -.54  -.95  -.62  -.75

# %%
df.Year=pd.to_numeric(df.Year, errors='coerce')
df.JD=pd.to_numeric(df.JD, errors='coerce')
df.Jan=pd.to_numeric(df.Jan, errors='coerce')
df.Feb=pd.to_numeric(df.Feb, errors='coerce')
df.Mar=pd.to_numeric(df.Mar, errors='coerce')
df.Apr=pd.to_numeric(df.Apr, errors='coerce')
df.May=pd.to_numeric(df.May, errors='coerce')
df.Jun=pd.to_numeric(df.Jun, errors='coerce')
df.Jul=pd.to_numeric(df.Jul, errors='coerce')
df.Aug=pd.to_numeric(df.Aug, errors='coerce')
df.Sep=pd.to_numeric(df.Sep, errors='coerce')
df.Oct=pd.to_numeric(df.Oct, errors='coerce')
df.Nov=pd.to_numeric(df.Nov, errors='coerce')
df.Dec=pd.to_numeric(df.Dec, errors='coerce')

# %%
x=df[u'Year']
y=df[u'JD']

# %%
mplt.plot(x,y, color='k')
mplt.grid(True)
mplt.title('Temperatura anual vs Año')
mplt.xlabel("Año")
mplt.ylabel("Temperatura anual")

mplt.show()

# %%
from scipy.interpolate import interp1d

mplt.plot(x,y, color='k', label='Annual Mean')
mplt.grid(True)
mplt.title('Anomalia original y suavizada vs Año')
mplt.xlabel("Año")
mplt.ylabel("Temperatura anual")

x=df[u'Year'] 
y=df[u'JD']
 

lowess = sm.nonparametric.lowess(y, x, frac=.3)

lowess_x = list(zip(*lowess))[0]
lowess_y = list(zip(*lowess))[1]

f = interp1d(lowess_x, lowess_y, bounds_error=False)

xnew = [i/10. for i in range(140)]

ynew = f(xnew)

plt.plot(x, y,'.',color='k')
plt.plot(lowess_x, lowess_y, color='r', label='Lowess')

plt.legend(loc="upper left") 
plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'JD', 'DN', 'DJF', 'MAM', 'JJA', 'SON'],
#       dtype='object')

# %%
df.boxplot(column=[u'Jan' , u'Feb' , u'Mar' , u'Apr' , u'May' , u'Jun' , u'Jul' , u'Aug' , u'Sep' , u'Oct' , u'Nov' , u'Dec'])
plt.title('Temperatura de los meses desde 1880 a 2017')
plt.ylabel('Variabilidad')
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
