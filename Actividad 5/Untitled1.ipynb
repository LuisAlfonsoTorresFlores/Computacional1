# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

df = pd.read_csv("/home/luistorres/Fisica_computacional/Act5/tpl_soloenero.csv",skiprows=1, names=["Año","Mes","Dia","Hora","Altura"])

# %%
df["Hora"]= pd.to_datetime(df["Hora"], format = '%Y %m %d %H:%M:')

# %%
df.Hora=pd.to_numeric(df.Hora, errors='coerce')
df.Altura=pd.to_numeric(df.Altura, errors='coerce')
x=df[u'Hora']
y=df[u'Altura']

# %%
matplotlib inline

# %%
#axes = plt.gca()
#axes.set_xlim([0,1])
plt.plot(x,y)
plt.title('Hora vs Altura Baltimore')
plt.xlabel("Hora")
plt.ylabel("Altura")
plt.grid(True)
plt.show()
